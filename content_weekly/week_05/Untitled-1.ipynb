# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from wqchartpy import triangle_piper

# Load the template dataset
df = pd.read_csv('/workspaces/hwrs564a_course_materials_xiradakis/content_weekly/week_05/datasets/Data_for_Project2.csv')

# Display the data
print("\nData shape:", df.shape)
df
# Out:
# Data shape: (3, 18)
#                         Unnamed: 0  Well    Ca   Mg    Na     K   Cl  HCO3  \
# 0 Upgradient Well                1    40   8.1   37   1.9    13  200    11
# 1 Downgradient Well              2    40  18.0  140   2.7    37  370    72
# 2 Well Near Gila River           3   650  97.0  670  11.0  1400  190  1600
#
#                           SO4  Barium    pH Temp (°C)  Label Color  Marker  \
# 0 Upgradient Well       0.000     7.2  31.8        #1    red     o     0.0
# 1 Downgradient Well     0.000     7.9  18.6        #2   blue     s     0.0
# 2 Well Near Gila River  0.043     7.7  21.4        #3  brown     x    30.0
#
#                         Size  Alpha  Sample
# 0 Upgradient Well       30.0    0.8     1.0
# 1 Downgradient Well     30.0    0.8     2.0
# 2 Well Near Gila River   0.8    3.0     NaN
